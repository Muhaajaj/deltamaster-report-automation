# %% [markdown]
# # DeltaMaster Report Automation — Colab Demo
#
# This notebook runs the project **exactly like the Fleet/DKV demo style**:
# 1) Install requirements from GitHub
# 2) Clone the repo
# 3) Run the script using the **sample synthetic files** in `data/sample/`

# %%
# !pip -q install -r "https://raw.githubusercontent.com/Muhaajaj/deltamaster-report-automation/main/requirements.txt"

# %%
# Clone repository
# !git clone "https://github.com/Muhaajaj/deltamaster-report-automation.git"
# %cd "deltamaster-report-automation"
# Out:
# Cloning into 'deltamaster-report-automation'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 55 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 226.10 KiB | 8.07 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/deltamaster-report-automation/deltamaster-report-automation/deltamaster-report-automation

# %%
# !mkdir -p outputs
# !python -u src/deltamaster_umbuchung_report.py \
  --topm "Data/Sample/DB1_Rohertrag_mit_FallPauschalen_SYNTH.xlsx" \
  --addison "Data/Sample/Rendite_SYNTH.xlsx" \
  --out "outputs/Ergebnis_final_strukturiert.xlsx"
# Out:
# Done. Output saved to: /content/deltamaster-report-automation/deltamaster-report-automation/deltamaster-report-automation/outputs/Ergebnis_final_strukturiert.xlsx

# %%
# !ls -lah Data
# !ls -lah Data/Sample
# !ls -lah outputs
# Out:
# total 12K
# drwxr-xr-x 3 root root 4.0K Dec 15 15:27 .
# drwxr-xr-x 6 root root 4.0K Dec 15 15:27 ..
# drwxr-xr-x 2 root root 4.0K Dec 15 15:27 Sample
# total 224K
# drwxr-xr-x 2 root root 4.0K Dec 15 15:27 .
# drwxr-xr-x 3 root root 4.0K Dec 15 15:27 ..
# -rw-r--r-- 1 root root 176K Dec 15 15:27 DB1_Rohertrag_mit_FallPauschalen_SYNTH.xlsx
# -rw-r--r-- 1 root root    1 Dec 15 15:27 .gitkeep
# -rw-r--r-- 1 root root  34K Dec 15 15:27 Rendite_SYNTH.xlsx
# total 32K
# drwxr-xr-x 2 root root 4.0K Dec 15 15:27 .
# drwxr-xr-x 6 root root 4.0K Dec 15 15:27 ..
# -rw-r--r-- 1 root root  18K Dec 15 15:27 Ergebnis_final_strukturiert.xlsx
# -rw-r--r-- 1 root root    1 Dec 15 15:27 .gitkeep

# %%
from google.colab import files
files.download("outputs/Ergebnis_final_strukturiert.xlsx")

# %%
# !ls -lah
# !ls -lah outputs || true
# !find . -maxdepth 4 -type f -iname "Ergebnis_final_strukturiert*.xlsx" -print
# Out:
# total 44K
# drwxr-xr-x 6 root root 4.0K Dec 15 15:14 .
# drwxr-xr-x 7 root root 4.0K Dec 15 15:14 ..
# drwxr-xr-x 3 root root 4.0K Dec 15 15:14 data
# drwxr-xr-x 8 root root 4.0K Dec 15 15:14 .git
# -rw-r--r-- 1 root root 4.6K Dec 15 15:14 .gitignore
# -rw-r--r-- 1 root root 1.1K Dec 15 15:14 LICENSE
# drwxr-xr-x 2 root root 4.0K Dec 15 15:14 outputs
# -rw-r--r-- 1 root root  987 Dec 15 15:14 README.md
# -rw-r--r-- 1 root root   22 Dec 15 15:14 requirements.txt
# drwxr-xr-x 2 root root 4.0K Dec 15 15:14 src
# total 12K
# drwxr-xr-x 2 root root 4.0K Dec 15 15:14 .
# drwxr-xr-x 6 root root 4.0K Dec 15 15:14 ..
# -rw-r--r-- 1 root root    1 Dec 15 15:14 .gitkeep
